# %%
import pandas as pd
import numpy as np
from scipy.stats import randint
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split
import seaborn as sns # used for plot interactive graph. 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import nltk
nltk.download('stopwords')

# %%
# Data loading from csv
df = pd.read_csv('test.csv')
df.shape

# %%
df
# Out:
#         id                                              tweet
# 0     7921  I hate the new #iphone upgrade. Won't let me d...
# 1     7922  currently shitting my fucking pants. #apple #i...
# 2     7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3     7924  My ipod is officially dead. I lost all my pict...
# 4     7925  Been fighting iTunes all night! I only want th...
# ...    ...                                                ...
# 1948  9869  #SamsungGalaxyNote7 Explodes, Burns 6-Year-Old...
# 1949  9870  Now Available - Hoodie. Check it out here - ht...
# 1950  9871  There goes a crack right across the screen. If...
# 1951  9872  @codeofinterest as i said #Adobe big time we m...
# 1952  9873  Finally I got it .. thanx my father .. #Samsun...
#
# [1953 rows x 2 columns]

# %%
df.head()
# Out:
#      id                                              tweet
# 0  7921  I hate the new #iphone upgrade. Won't let me d...
# 1  7922  currently shitting my fucking pants. #apple #i...
# 2  7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3  7924  My ipod is officially dead. I lost all my pict...
# 4  7925  Been fighting iTunes all night! I only want th...

# %%
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
df['score2'] = df['tweet'].apply(lambda review: sid.polarity_scores(review))

df.head()
# Out:
#      id                                              tweet  \
# 0  7921  I hate the new #iphone upgrade. Won't let me d...
# 1  7922  currently shitting my fucking pants. #apple #i...
# 2  7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3  7924  My ipod is officially dead. I lost all my pict...
# 4  7925  Been fighting iTunes all night! I only want th...
#
#                                               score2
# 0  {'neg': 0.36, 'neu': 0.64, 'pos': 0.0, 'compou...
# 1  {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...
# 3  {'neg': 0.248, 'neu': 0.752, 'pos': 0.0, 'comp...
# 4  {'neg': 0.198, 'neu': 0.71, 'pos': 0.092, 'com...

# %%
df['compound']  = df['score2'].apply(lambda score_dict: score_dict['compound'])

df.head()
# Out:
#      id                                              tweet  \
# 0  7921  I hate the new #iphone upgrade. Won't let me d...
# 1  7922  currently shitting my fucking pants. #apple #i...
# 2  7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3  7924  My ipod is officially dead. I lost all my pict...
# 4  7925  Been fighting iTunes all night! I only want th...
#
#                                               score2  compound
# 0  {'neg': 0.36, 'neu': 0.64, 'pos': 0.0, 'compou...   -0.7351
# 1  {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'comp...   -0.4215
# 2  {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...    0.7243
# 3  {'neg': 0.248, 'neu': 0.752, 'pos': 0.0, 'comp...   -0.7650
# 4  {'neg': 0.198, 'neu': 0.71, 'pos': 0.092, 'com...   -0.3595

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')

df.head()
# Out:
#      id                                              tweet  \
# 0  7921  I hate the new #iphone upgrade. Won't let me d...
# 1  7922  currently shitting my fucking pants. #apple #i...
# 2  7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3  7924  My ipod is officially dead. I lost all my pict...
# 4  7925  Been fighting iTunes all night! I only want th...
#
#                                               score2  compound comp_score
# 0  {'neg': 0.36, 'neu': 0.64, 'pos': 0.0, 'compou...   -0.7351        neg
# 1  {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'comp...   -0.4215        neg
# 2  {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...    0.7243        pos
# 3  {'neg': 0.248, 'neu': 0.752, 'pos': 0.0, 'comp...   -0.7650        neg
# 4  {'neg': 0.198, 'neu': 0.71, 'pos': 0.092, 'com...   -0.3595        neg

# %%
df = df.sort_values(by ='compound' )
print("Contents of Sorted Dataframe based on a single column 'compound' : ")
df
# Out:
# Contents of Sorted Dataframe based on a single column 'compound' :
#         id                                              tweet  \
# 1556  9477  Fuck iPhones. Fuck them fuck them fuck them fu...
# 1598  9519  Fuck you #apple. Fuck you for being a shitty #...
# 366   8287  (YouTube) The Murder of Antoinette Chase – Mur...
# 486   8407  Dear #iphone5 FUCK YOU!! YOURE MAKING MY 4 CRA...
# 28    7949  My iPhone 5 charger has broken. I bought two n...
# ...    ...                                                ...
# 595   8516  I'm minorly inconvenienced, but they're taking...
# 1745  9666  Was at the apple store today - what an experie...
# 458   8379  Wow what a great day. #iphonex arrived and it’...
# 759   8680  #May the divine blessings of Allah bring you h...
# 92    8013  My wonderful husband just bought me the new #i...
#
#                                                  score2  compound comp_score  \
# 1556  {'neg': 0.758, 'neu': 0.242, 'pos': 0.0, 'comp...   -0.9715        neg
# 1598  {'neg': 0.435, 'neu': 0.513, 'pos': 0.051, 'co...   -0.9623        neg
# 366   {'neg': 0.432, 'neu': 0.568, 'pos': 0.0, 'comp...   -0.9403        neg
# 486   {'neg': 0.411, 'neu': 0.511, 'pos': 0.078, 'co...   -0.9197        neg
# 28    {'neg': 0.481, 'neu': 0.519, 'pos': 0.0, 'comp...   -0.9186        neg
# ...                                                 ...       ...        ...
# 595   {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'comp...    0.9428        pos
# 1745  {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'comp...    0.9474        pos
# 458   {'neg': 0.0, 'neu': 0.456, 'pos': 0.544, 'comp...    0.9477        pos
# 759   {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'comp...    0.9508        pos
# 92    {'neg': 0.0, 'neu': 0.527, 'pos': 0.473, 'comp...    0.9526        pos
#
#       length
# 1556      73
# 1598     228
# 366      316
# 486      122
# 28       103
# ...      ...
# 595      123
# 1745     106
# 458      117
# 759      297
# 92       118
#
# [1953 rows x 6 columns]

# %%
df.describe()
# Out:
#                 id     compound       length
# count  1953.000000  1953.000000  1953.000000
# mean   8897.000000     0.143791   126.462878
# std     563.926857     0.423073    44.345049
# min    7921.000000    -0.971500    45.000000
# 25%    8409.000000     0.000000   106.000000
# 50%    8897.000000     0.000000   123.000000
# 75%    9385.000000     0.493900   131.000000
# max    9873.000000     0.952600   383.000000

# %%
df.groupby('comp_score').describe()
# Out:
#                 id                                                             \
#              count         mean         std     min      25%     50%      75%
# comp_score
# neg          363.0  8881.754821  575.519398  7921.0  8363.50  8845.0  9361.50
# pos         1590.0  8900.480503  561.372582  7923.0  8417.25  8904.5  9386.75
#
#                    compound            ...                  length  \
#                max    count      mean  ...     75%     max   count
# comp_score                             ...
# neg         9861.0    363.0 -0.475313  ... -0.2960 -0.0258   363.0
# pos         9873.0   1590.0  0.285134  ...  0.5859  0.9526  1590.0
#
#
#                   mean        std   min    25%    50%    75%    max
# comp_score
# neg         117.079890  43.944738  48.0   92.0  117.0  129.0  371.0
# pos         128.605031  44.170902  45.0  109.0  124.0  132.0  383.0
#
# [2 rows x 24 columns]

# %%
df['length'] = df['tweet'].apply(len)
df.head()
# Out:
#         id                                              tweet  \
# 1556  9477  Fuck iPhones. Fuck them fuck them fuck them fu...
# 1598  9519  Fuck you #apple. Fuck you for being a shitty #...
# 366   8287  (YouTube) The Murder of Antoinette Chase – Mur...
# 486   8407  Dear #iphone5 FUCK YOU!! YOURE MAKING MY 4 CRA...
# 28    7949  My iPhone 5 charger has broken. I bought two n...
#
#                                                  score2  compound comp_score  \
# 1556  {'neg': 0.758, 'neu': 0.242, 'pos': 0.0, 'comp...   -0.9715        neg
# 1598  {'neg': 0.435, 'neu': 0.513, 'pos': 0.051, 'co...   -0.9623        neg
# 366   {'neg': 0.432, 'neu': 0.568, 'pos': 0.0, 'comp...   -0.9403        neg
# 486   {'neg': 0.411, 'neu': 0.511, 'pos': 0.078, 'co...   -0.9197        neg
# 28    {'neg': 0.481, 'neu': 0.519, 'pos': 0.0, 'comp...   -0.9186        neg
#
#       length
# 1556      73
# 1598     228
# 366      316
# 486      122
# 28       103

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df['length'].plot(bins=100, kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.length.describe()
# Out:
# count    1953.000000
# mean      126.462878
# std        44.345049
# min        45.000000
# 25%       106.000000
# 50%       123.000000
# 75%       131.000000
# max       383.000000
# Name: length, dtype: float64

# %%
df.hist(column='length', by='comp_score', bins=50,figsize=(20,6))
# Out:
# array([<AxesSubplot:title={'center':'neg'}>,
#        <AxesSubplot:title={'center':'pos'}>], dtype=object)
