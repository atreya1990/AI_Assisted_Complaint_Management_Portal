# %%
pip install mysql
# Out:
# Requirement already satisfied: mysql in c:\users\raora\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: mysqlclient in c:\users\raora\anaconda3\lib\site-packages (from mysql) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip search mysql-connector | grep --color mysql-connector-python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
 pip install PyMySQL
# Out:
# Requirement already satisfied: PyMySQL in c:\users\raora\anaconda3\lib\site-packages (0.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='cms', user='root', password='')
db_cursor = db_connection.cursor()
db_cursor.execute('SELECT * FROM tblcomplaints')

table_rows = db_cursor.fetchall()

df = pd.DataFrame(table_rows)

# %%
pip install mysql-connector-python-rf
# Out:
# Requirement already satisfied: mysql-connector-python-rf in c:\users\raora\anaconda3\lib\site-packages (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pymysql

db_connection_str = 'mysql+pymysql://root:@localhost/cms'
db_connection = create_engine(db_connection_str)

df = pd.read_sql('SELECT * FROM tblcomplaints', con=db_connection)

# %%
df
# Out:
#     complaintNumber  userId  category             subcategory  complaintType  \
# 0                25       1         3  irregular water supply  General Query
# 1                27       1         4         voltage problem  General Query
# 2                28       2         5                potholes  General Query
# 3                29       1         3  irregular water supply  General Query
# 4                30       1         4           load shedding  General Query
# 5                31       1         5                potholes  General Query
# 6                32       1         4         voltage problem  General Query
# 7                33       1         4           load shedding  General Query
# 8                34       2         5                potholes  General Query
# 9                35       1         5                potholes  General Query
# 10               36       1         4         voltage problem  General Query
# 11               37       1         3      contaminated water      Complaint
# 12               38       1         4         voltage problem      Complaint
# 13               39       1         4         voltage problem      Complaint
# 14               40       1         3  irregular water supply      Complaint
#
#             state                  noc  \
# 0          Punjab         water supply
# 1         Haryana  voltage fluctuation
# 2           Delhi            bad roads
# 3          Punjab  voltage fluctuation
# 4           Delhi  voltage fluctuation
# 5          Punjab            bad roads
# 6          Punjab  voltage fluctuation
# 7   Uttar Pradesh  voltage fluctuation
# 8   Uttar Pradesh         water supply
# 9   Uttar Pradesh         water supply
# 10         Punjab  voltage fluctuation
# 11        Haryana         water supply
# 12          Delhi  voltage fluctuation
# 13          Delhi  voltage fluctuation
# 14         Punjab         water supply
#
#                                      complaintDetails           complaintFile  \
# 0   my water supply is irregular . and not coming ...
# 1   eletronics not working properly because of irr...            customer.csv
# 2   roads are in a very bad shape and they cause m...
# 3   I am calling to report a plumbing issue in my ...
# 4   I am calling to report a problem with our elec...
# 5   I am calling to report an issue with our washe...
# 6   My name is Monica Thomson. I am in 1B. My gara...
# 7   My name is Avery Howard. I am in 2B. My heater...
# 8   My name is Avery Howard. I am in 2B. My heater...
# 9   My name is Avery Howard. I am in 2B. My heater...
# 10                         electricity out for 5 days
# 11                                  water is very bad
# 12                             i have voltage problem  PPT FINAL PROJECT.pptx
# 13                             i have voltage problem  PPT FINAL PROJECT.pptx
# 14  irrigulay water supply . i am facing a lot of ...
#
#                regDate      status    lastUpdationDate
# 0  2020-12-05 04:21:13      closed 2020-12-10 10:20:26
# 1  2020-12-05 04:26:46  in process 2020-12-05 12:25:19
# 2  2020-12-05 10:38:13      closed 2020-12-05 10:43:16
# 3  2020-12-05 11:14:11      closed 2020-12-05 15:42:50
# 4  2020-12-05 11:14:36  in process 2021-03-12 14:18:26
# 5  2020-12-05 11:15:04      closed 2021-03-12 15:52:27
# 6  2020-12-05 11:15:33      closed 2021-03-24 14:03:15
# 7  2020-12-05 11:15:59      closed 2021-03-24 14:05:07
# 8  2020-12-05 11:48:41      closed 2021-03-24 14:07:42
# 9  2020-12-05 11:49:23        None                 NaT
# 10 2020-12-05 12:26:43        None                 NaT
# 11 2020-12-10 11:00:12        None                 NaT
# 12 2020-12-10 11:32:51      closed 2020-12-10 11:34:46
# 13 2020-12-10 11:50:25        None                 NaT
# 14 2021-03-24 14:12:53        None                 NaT

# %%
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
df['score2'] = df['complaintDetails'].apply(lambda review: sid.polarity_scores(review))

df.head()
# Out:
#    complaintNumber  userId  category             subcategory  complaintType  \
# 0               25       1         3  irregular water supply  General Query
# 1               27       1         4         voltage problem  General Query
# 2               28       2         5                potholes  General Query
# 3               29       1         3  irregular water supply  General Query
# 4               30       1         4           load shedding  General Query
#
#      state                  noc  \
# 0   Punjab         water supply
# 1  Haryana  voltage fluctuation
# 2    Delhi            bad roads
# 3   Punjab  voltage fluctuation
# 4    Delhi  voltage fluctuation
#
#                                     complaintDetails complaintFile  \
# 0  my water supply is irregular . and not coming ...
# 1  eletronics not working properly because of irr...  customer.csv
# 2  roads are in a very bad shape and they cause m...
# 3  I am calling to report a plumbing issue in my ...
# 4  I am calling to report a problem with our elec...
#
#               regDate      status    lastUpdationDate  \
# 0 2020-12-05 04:21:13      closed 2020-12-10 10:20:26
# 1 2020-12-05 04:26:46  in process 2020-12-05 12:25:19
# 2 2020-12-05 10:38:13      closed 2020-12-05 10:43:16
# 3 2020-12-05 11:14:11      closed 2020-12-05 15:42:50
# 4 2020-12-05 11:14:36  in process 2021-03-12 14:18:26
#
#                                               score2
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'comp...
# 3  {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'comp...
# 4  {'neg': 0.129, 'neu': 0.81, 'pos': 0.062, 'com...

# %%
df['compound']  = df['score2'].apply(lambda score_dict: score_dict['compound'])

df.head()
# Out:
#    complaintNumber  userId  category             subcategory  complaintType  \
# 0               25       1         3  irregular water supply  General Query
# 1               27       1         4         voltage problem  General Query
# 2               28       2         5                potholes  General Query
# 3               29       1         3  irregular water supply  General Query
# 4               30       1         4           load shedding  General Query
#
#      state                  noc  \
# 0   Punjab         water supply
# 1  Haryana  voltage fluctuation
# 2    Delhi            bad roads
# 3   Punjab  voltage fluctuation
# 4    Delhi  voltage fluctuation
#
#                                     complaintDetails complaintFile  \
# 0  my water supply is irregular . and not coming ...
# 1  eletronics not working properly because of irr...  customer.csv
# 2  roads are in a very bad shape and they cause m...
# 3  I am calling to report a plumbing issue in my ...
# 4  I am calling to report a problem with our elec...
#
#               regDate      status    lastUpdationDate  \
# 0 2020-12-05 04:21:13      closed 2020-12-10 10:20:26
# 1 2020-12-05 04:26:46  in process 2020-12-05 12:25:19
# 2 2020-12-05 10:38:13      closed 2020-12-05 10:43:16
# 3 2020-12-05 11:14:11      closed 2020-12-05 15:42:50
# 4 2020-12-05 11:14:36  in process 2021-03-12 14:18:26
#
#                                               score2  compound
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2  {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'comp...   -0.8313
# 3  {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'comp...    0.0772
# 4  {'neg': 0.129, 'neu': 0.81, 'pos': 0.062, 'com...   -0.3400

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')

df.head()
# Out:
#    complaintNumber  userId  category             subcategory  complaintType  \
# 0               25       1         3  irregular water supply  General Query
# 1               27       1         4         voltage problem  General Query
# 2               28       2         5                potholes  General Query
# 3               29       1         3  irregular water supply  General Query
# 4               30       1         4           load shedding  General Query
#
#      state                  noc  \
# 0   Punjab         water supply
# 1  Haryana  voltage fluctuation
# 2    Delhi            bad roads
# 3   Punjab  voltage fluctuation
# 4    Delhi  voltage fluctuation
#
#                                     complaintDetails complaintFile  \
# 0  my water supply is irregular . and not coming ...
# 1  eletronics not working properly because of irr...  customer.csv
# 2  roads are in a very bad shape and they cause m...
# 3  I am calling to report a plumbing issue in my ...
# 4  I am calling to report a problem with our elec...
#
#               regDate      status    lastUpdationDate  \
# 0 2020-12-05 04:21:13      closed 2020-12-10 10:20:26
# 1 2020-12-05 04:26:46  in process 2020-12-05 12:25:19
# 2 2020-12-05 10:38:13      closed 2020-12-05 10:43:16
# 3 2020-12-05 11:14:11      closed 2020-12-05 15:42:50
# 4 2020-12-05 11:14:36  in process 2021-03-12 14:18:26
#
#                                               score2  compound comp_score
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 2  {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'comp...   -0.8313        neg
# 3  {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'comp...    0.0772        pos
# 4  {'neg': 0.129, 'neu': 0.81, 'pos': 0.062, 'com...   -0.3400        neg

# %%
df = df.sort_values(by ='compound' )
print("Contents of Sorted Dataframe based on a single column 'Name' : ")
print(df)
# Out:
# Contents of Sorted Dataframe based on a single column 'Name' :
#     complaintNumber  userId  category             subcategory  complaintType  \
# 2                28       2         5                potholes  General Query
# 11               37       1         3      contaminated water      Complaint
# 12               38       1         4         voltage problem      Complaint
# 13               39       1         4         voltage problem      Complaint
# 14               40       1         3  irregular water supply      Complaint
# 4                30       1         4           load shedding  General Query
# 6                32       1         4         voltage problem  General Query
# 7                33       1         4           load shedding  General Query
# 8                34       2         5                potholes  General Query
# 9                35       1         5                potholes  General Query
# 0                25       1         3  irregular water supply  General Query
# 1                27       1         4         voltage problem  General Query
# 10               36       1         4         voltage problem  General Query
# 3                29       1         3  irregular water supply  General Query
# 5                31       1         5                potholes  General Query
#
#             state                  noc  \
# 2           Delhi            bad roads
# 11        Haryana         water supply
# 12          Delhi  voltage fluctuation
# 13          Delhi  voltage fluctuation
# 14         Punjab         water supply
# 4           Delhi  voltage fluctuation
# 6          Punjab  voltage fluctuation
# 7   Uttar Pradesh  voltage fluctuation
# 8   Uttar Pradesh         water supply
# 9   Uttar Pradesh         water supply
# 0          Punjab         water supply
# 1         Haryana  voltage fluctuation
# 10         Punjab  voltage fluctuation
# 3          Punjab  voltage fluctuation
# 5          Punjab            bad roads
#
#                                      complaintDetails           complaintFile  \
# 2   roads are in a very bad shape and they cause m...
# 11                                  water is very bad
# 12                             i have voltage problem  PPT FINAL PROJECT.pptx
# 13                             i have voltage problem  PPT FINAL PROJECT.pptx
# 14  irrigulay water supply . i am facing a lot of ...
# 4   I am calling to report a problem with our elec...
# 6   My name is Monica Thomson. I am in 1B. My gara...
# 7   My name is Avery Howard. I am in 2B. My heater...
# 8   My name is Avery Howard. I am in 2B. My heater...
# 9   My name is Avery Howard. I am in 2B. My heater...
# 0   my water supply is irregular . and not coming ...
# 1   eletronics not working properly because of irr...            customer.csv
# 10                         electricity out for 5 days
# 3   I am calling to report a plumbing issue in my ...
# 5   I am calling to report an issue with our washe...
#
#                regDate      status    lastUpdationDate  \
# 2  2020-12-05 10:38:13      closed 2020-12-05 10:43:16
# 11 2020-12-10 11:00:12        None                 NaT
# 12 2020-12-10 11:32:51      closed 2020-12-10 11:34:46
# 13 2020-12-10 11:50:25        None                 NaT
# 14 2021-03-24 14:12:53        None                 NaT
# 4  2020-12-05 11:14:36  in process 2021-03-12 14:18:26
# 6  2020-12-05 11:15:33      closed 2021-03-24 14:03:15
# 7  2020-12-05 11:15:59      closed 2021-03-24 14:05:07
# 8  2020-12-05 11:48:41      closed 2021-03-24 14:07:42
# 9  2020-12-05 11:49:23        None                 NaT
# 0  2020-12-05 04:21:13      closed 2020-12-10 10:20:26
# 1  2020-12-05 04:26:46  in process 2020-12-05 12:25:19
# 10 2020-12-05 12:26:43        None                 NaT
# 3  2020-12-05 11:14:11      closed 2020-12-05 15:42:50
# 5  2020-12-05 11:15:04      closed 2021-03-12 15:52:27
#
#                                                score2  compound comp_score
# 2   {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'comp...   -0.8313        neg
# 11  {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'comp...   -0.5849        neg
# 12  {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...   -0.4019        neg
# 13  {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...   -0.4019        neg
# 14  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...   -0.4019        neg
# 4   {'neg': 0.129, 'neu': 0.81, 'pos': 0.062, 'com...   -0.3400        neg
# 6   {'neg': 0.098, 'neu': 0.902, 'pos': 0.0, 'comp...   -0.2411        neg
# 7   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...   -0.2411        neg
# 8   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...   -0.2411        neg
# 9   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...   -0.2411        neg
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 3   {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'comp...    0.0772        pos
# 5   {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...    0.0772        pos

# %%
df
# Out:
#     complaintNumber  userId  category             subcategory  complaintType  \
# 2                28       2         5                potholes  General Query
# 11               37       1         3      contaminated water      Complaint
# 12               38       1         4         voltage problem      Complaint
# 13               39       1         4         voltage problem      Complaint
# 14               40       1         3  irregular water supply      Complaint
# 4                30       1         4           load shedding  General Query
# 6                32       1         4         voltage problem  General Query
# 7                33       1         4           load shedding  General Query
# 8                34       2         5                potholes  General Query
# 9                35       1         5                potholes  General Query
# 0                25       1         3  irregular water supply  General Query
# 1                27       1         4         voltage problem  General Query
# 10               36       1         4         voltage problem  General Query
# 3                29       1         3  irregular water supply  General Query
# 5                31       1         5                potholes  General Query
#
#             state                  noc  \
# 2           Delhi            bad roads
# 11        Haryana         water supply
# 12          Delhi  voltage fluctuation
# 13          Delhi  voltage fluctuation
# 14         Punjab         water supply
# 4           Delhi  voltage fluctuation
# 6          Punjab  voltage fluctuation
# 7   Uttar Pradesh  voltage fluctuation
# 8   Uttar Pradesh         water supply
# 9   Uttar Pradesh         water supply
# 0          Punjab         water supply
# 1         Haryana  voltage fluctuation
# 10         Punjab  voltage fluctuation
# 3          Punjab  voltage fluctuation
# 5          Punjab            bad roads
#
#                                      complaintDetails           complaintFile  \
# 2   roads are in a very bad shape and they cause m...
# 11                                  water is very bad
# 12                             i have voltage problem  PPT FINAL PROJECT.pptx
# 13                             i have voltage problem  PPT FINAL PROJECT.pptx
# 14  irrigulay water supply . i am facing a lot of ...
# 4   I am calling to report a problem with our elec...
# 6   My name is Monica Thomson. I am in 1B. My gara...
# 7   My name is Avery Howard. I am in 2B. My heater...
# 8   My name is Avery Howard. I am in 2B. My heater...
# 9   My name is Avery Howard. I am in 2B. My heater...
# 0   my water supply is irregular . and not coming ...
# 1   eletronics not working properly because of irr...            customer.csv
# 10                         electricity out for 5 days
# 3   I am calling to report a plumbing issue in my ...
# 5   I am calling to report an issue with our washe...
#
#                regDate      status    lastUpdationDate  \
# 2  2020-12-05 10:38:13      closed 2020-12-05 10:43:16
# 11 2020-12-10 11:00:12        None                 NaT
# 12 2020-12-10 11:32:51      closed 2020-12-10 11:34:46
# 13 2020-12-10 11:50:25        None                 NaT
# 14 2021-03-24 14:12:53        None                 NaT
# 4  2020-12-05 11:14:36  in process 2021-03-12 14:18:26
# 6  2020-12-05 11:15:33      closed 2021-03-24 14:03:15
# 7  2020-12-05 11:15:59      closed 2021-03-24 14:05:07
# 8  2020-12-05 11:48:41      closed 2021-03-24 14:07:42
# 9  2020-12-05 11:49:23        None                 NaT
# 0  2020-12-05 04:21:13      closed 2020-12-10 10:20:26
# 1  2020-12-05 04:26:46  in process 2020-12-05 12:25:19
# 10 2020-12-05 12:26:43        None                 NaT
# 3  2020-12-05 11:14:11      closed 2020-12-05 15:42:50
# 5  2020-12-05 11:15:04      closed 2021-03-12 15:52:27
#
#                                                score2  compound comp_score
# 2   {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'comp...   -0.8313        neg
# 11  {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'comp...   -0.5849        neg
# 12  {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...   -0.4019        neg
# 13  {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'comp...   -0.4019        neg
# 14  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...   -0.4019        neg
# 4   {'neg': 0.129, 'neu': 0.81, 'pos': 0.062, 'com...   -0.3400        neg
# 6   {'neg': 0.098, 'neu': 0.902, 'pos': 0.0, 'comp...   -0.2411        neg
# 7   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...   -0.2411        neg
# 8   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...   -0.2411        neg
# 9   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...   -0.2411        neg
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 3   {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'comp...    0.0772        pos
# 5   {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...    0.0772        pos

# %%
tableName="abc" 
frame = df.to_sql(tableName, db_connection, if_exists='fail');
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     187             assert q_values[0] == '(' and q_values[-1] == ')'
# --> 188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near ''neg': '0.403e0', 'neu': '0.597e0', 'pos': '0.0e0', 'compound': '-0.8313e0'},...' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-18-4cb5a0931e74> in <module>
#       1 tableName="abc"
# ----> 2 frame = df.to_sql(tableName, db_connection, if_exists='fail');
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     146
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#     150             context._rowcount = rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     186             q_postfix = m.group(3) or ''
#     187             assert q_values[0] == '(' and q_values[-1] == ')'
# --> 188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
#     190                                          self._get_db().encoding)
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     225                 sql += b','
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#     229         return rows
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near ''neg': '0.403e0', 'neu': '0.597e0', 'pos': '0.0e0', 'compound': '-0.8313e0'},...' at line 1")
# [SQL: INSERT INTO abc (`index`, `complaintNumber`, `userId`, category, subcategory, `complaintType`, state, noc, `complaintDetails`, `complaintFile`, `regDate`, status, `lastUpdationDate`, score2, compound, comp_score) VALUES (%(index)s, %(complaintNumber)s, %(userId)s, %(category)s, %(subcategory)s, %(complaintType)s, %(state)s, %(noc)s, %(complaintDetails)s, %(complaintFile)s, %(regDate)s, %(status)s, %(lastUpdationDate)s, %(score2)s, %(compound)s, %(comp_score)s)]
# [parameters: ({'index': 2, 'complaintNumber': 28, 'userId': 2, 'category': 5, 'subcategory': 'potholes', 'complaintType': 'General Query', 'state': 'Delhi', 'noc': 'bad roads', 'complaintDetails': 'roads are in a very bad shape and they cause many accidents . many people have been injured', 'complaintFile': '', 'regDate': datetime.datetime(2020, 12, 5, 10, 38, 13), 'status': 'closed', 'lastUpdationDate': datetime.datetime(2020, 12, 5, 10, 43, 16), 'score2': {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.8313}, 'compound': -0.8313, 'comp_score': 'neg'}, {'index': 11, 'complaintNumber': 37, 'userId': 1, 'category': 3, 'subcategory': 'contaminated water', 'complaintType': ' Complaint', 'state': 'Haryana', 'noc': 'water supply', 'complaintDetails': 'water is very bad', 'complaintFile': '', 'regDate': datetime.datetime(2020, 12, 10, 11, 0, 12), 'status': None, 'lastUpdationDate': None, 'score2': {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'compound': -0.5849}, 'compound': -0.5849, 'comp_score': 'neg'}, {'index': 12, 'complaintNumber': 38, 'userId': 1, 'category': 4, 'subcategory': 'voltage problem', 'complaintType': ' Complaint', 'state': 'Delhi', 'noc': 'voltage fluctuation', 'complaintDetails': 'i have voltage problem', 'complaintFile': 'PPT FINAL PROJECT.pptx', 'regDate': datetime.datetime(2020, 12, 10, 11, 32, 51), 'status': 'closed', 'lastUpdationDate': datetime.datetime(2020, 12, 10, 11, 34, 46), 'score2': {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4019}, 'compound': -0.4019, 'comp_score': 'neg'}, {'index': 13, 'complaintNumber': 39, 'userId': 1, 'category': 4, 'subcategory': 'voltage problem', 'complaintType': ' Complaint', 'state': 'Delhi', 'noc': 'voltage fluctuation', 'complaintDetails': 'i have voltage problem', 'complaintFile': 'PPT FINAL PROJECT.pptx', 'regDate': datetime.datetime(2020, 12, 10, 11, 50, 25), 'status': None, 'lastUpdationDate': None, 'score2': {'neg': 0.574, 'neu': 0.426, 'pos': 0.0, 'compound': -0.4019}, 'compound': -0.4019, 'comp_score': 'neg'}, {'index': 14, 'complaintNumber': 40, 'userId': 1, 'category': 3, 'subcategory': 'irregular water supply', 'complaintType': ' Complaint', 'state': 'Punjab', 'noc': 'water supply', 'complaintDetails': 'irrigulay water supply . i am facing a lot of problem', 'complaintFile': '', 'regDate': datetime.datetime(2021, 3, 24, 14, 12, 53), 'status': None, 'lastUpdationDate': None, 'score2': {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'compound': -0.4019}, 'compound': -0.4019, 'comp_score': 'neg'}, {'index': 4, 'complaintNumber': 30, 'userId': 1, 'category': 4, 'subcategory': 'load shedding', 'complaintType': 'General Query', 'state': 'Delhi', 'noc': 'voltage fluctuation', 'complaintDetails': 'I am calling to report a problem with our electricity. My name is Maya Robinson. And my phone number is 305-555-0122.\r\n', 'complaintFile': '', 'regDate': datetime.datetime(2020, 12, 5, 11, 14, 36), 'status': 'in process', 'lastUpdationDate': datetime.datetime(2021, 3, 12, 14, 18, 26), 'score2': {'neg': 0.129, 'neu': 0.81, 'pos': 0.062, 'compound': -0.34}, 'compound': -0.34, 'comp_score': 'neg'}, {'index': 6, 'complaintNumber': 32, 'userId': 1, 'category': 4, 'subcategory': 'voltage problem', 'complaintType': 'General Query', 'state': 'Punjab', 'noc': 'voltage fluctuation', 'complaintDetails': 'My name is Monica Thomson. I am in 1B. My garage door is not opening. Please call me at 360-555-0122.\r\n', 'complaintFile': '', 'regDate': datetime.datetime(2020, 12, 5, 11, 15, 33), 'status': 'closed', 'lastUpdationDate': datetime.datetime(2021, 3, 24, 14, 3, 15), 'score2': {'neg': 0.098, 'neu': 0.902, 'pos': 0.0, 'compound': -0.2411}, 'compound': -0.2411, 'comp_score': 'neg'}, {'index': 7, 'complaintNumber': 33, 'userId': 1, 'category': 4, 'subcategory': 'load shedding', 'complaintType': 'General Query', 'state': 'Uttar Pradesh', 'noc': 'voltage fluctuation', 'complaintDetails': 'My name is Avery Howard. I am in 2B. My heater is not working. Please call me at 604-555-0122. ...
# (Background on this error at: http://sqlalche.me/e/13/f405)
